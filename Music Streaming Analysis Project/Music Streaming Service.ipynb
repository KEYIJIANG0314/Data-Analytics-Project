# %%
import numpy as np
import pandas as pd

# %%
df_n = pd.read_excel('Music Streaming Service.xlsx')
df_n.head()
# Out:
#                     Q1  Q2_1                                  Q3 Q3_9_TEXT  \
# 0                  NaN   NaN                             Spotify       NaN
# 1              Everday   1.9  Spotify,Amazon Music,Youtube Music       NaN
# 2              Everday   2.0                         Apple Music       NaN
# 3  5 to 6 times a week   2.0                             Spotify       NaN
# 4              Everday   5.0               Spotify,Youtube Music       NaN
#
#              Q4 Q4_10_TEXT  Q5_1  Q5_2  Q5_3  Q5_4  ...  Q13_6  Q13_6_TEXT  \
# 0       Spotify        NaN   3.0   5.0   NaN   7.0  ...    NaN         NaN
# 1  Amazon Music        NaN   NaN   4.0   2.0   NaN  ...    NaN         NaN
# 2   Apple Music        NaN   5.0   7.0   7.0   7.0  ...    0.0         NaN
# 3       Spotify        NaN   1.0   1.0   1.0   3.0  ...    NaN         NaN
# 4       Spotify        NaN   NaN   7.0   6.0   4.0  ...    NaN         NaN
#
# ...

# %%
df_n.columns
# Out:
# Index(['Q1', 'Q2_1', 'Q3', 'Q3_9_TEXT', 'Q4', 'Q4_10_TEXT', 'Q5_1', 'Q5_2',
#        'Q5_3', 'Q5_4', 'Q5_5', 'Q5_6', 'Q6', 'Q6_6_TEXT', 'Q7_1', 'Q8_1',
#        'Q8_2', 'Q8_3', 'Q8_4', 'Q8_5', 'Q8_6', 'Q9_1', 'Q9_2', 'Q9_3', 'Q9_4',
#        'Q9_5', 'Q9_6', 'Q9_7', 'Q10_1', 'Q10_1_TEXT', 'Q11_17', 'Q12_1',
#        'Q12_2', 'Q12_3', 'Q12_4', 'Q12_5', 'Q12_6', 'Q12_7', 'Q12_7_TEXT',
#        'Q13_1', 'Q13_2', 'Q13_3', 'Q13_4', 'Q13_5', 'Q13_7', 'Q13_6',
#        'Q13_6_TEXT', 'Q14', 'Q15', 'Q16', 'Q16_5_TEXT', 'Q17', 'Q18', 'Q19',
#        'Q20'],
#       dtype='object')

# %%
df = df_n
labels = df['Q1'].unique().tolist()
df['Q1'] = df['Q1'].apply(lambda x: labels.index(x))
sns.regplot(x=df['Q1'],y=df['Q10_1'])
# Out:
# <AxesSubplot:xlabel='Q1', ylabel='Q10_1'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_n.loc[:,'Q8_1':'Q9_6']
# Out:
#     Q8_1  Q8_2  Q8_3  Q8_4  Q8_5  Q8_6  Q9_1  Q9_2  Q9_3  Q9_4  Q9_5  Q9_6
# 0    6.0   7.0   6.0   6.0   7.0   3.0   5.0   6.0   5.0   7.0   6.0   7.0
# 1    6.0   6.0   6.0   2.0   6.0   2.0   5.0   5.0   6.0   4.0   5.0   2.0
# 2    5.0   7.0   6.0   7.0   2.0   4.0   7.0   7.0   7.0   7.0   7.0   7.0
# 3    5.0   5.0   3.0   3.0   3.0   5.0   5.0   5.0   5.0   5.0   5.0   5.0
# 4    7.0   7.0   5.0   7.0   3.0   5.0   7.0   7.0   4.0   3.0   4.0   7.0
# 5    5.0   5.0   5.0   5.0   5.0   2.0   NaN   NaN   NaN   NaN   NaN   NaN
# 6    7.0   5.0   5.0   6.0   6.0   3.0   6.0   7.0   5.0   7.0   5.0   3.0
# 7    6.0   6.0   6.0   NaN   6.0   6.0   NaN   NaN   NaN   NaN   NaN   NaN
# 8    5.0   6.0   7.0   1.0   6.0   1.0   7.0   7.0   7.0   4.0   7.0   4.0
# 9    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10   7.0   7.0   7.0   7.0   4.0   7.0   5.0   6.0   4.0   7.0   4.0   7.0
# ...

# %%
df_1 = df_n.loc[:,'Q4':'Q5_6']
df_1 = df_1.drop(['Q4_10_TEXT'],axis=1)
df_1 = df_1.dropna()

# %%
df_1 = df_1.rename(columns={"Q4": "Current Music Streaming Service", "Q5_1": "Recommend by A Friend",
                     "Q5_2": "Price", "Q5_3": "Family plan",
                    "Q5_4": "Advertisements", "Q5_5": "Music Recommendations",
                    "Q5_6": "Collaborative Playlist Features"})

# %%
labels = df_1['Current Music Streaming Service'].unique().tolist()
df_1['Current Music Streaming Service'] = df_1['Current Music Streaming Service'].apply(lambda x: labels.index(x))

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df_1.corr(), vmax=.8, linewidths=0.01,square=True,annot=True,cmap='YlGnBu' ,linecolor="white")
plt.title('Correlation between Influence to selection')
# Out:
# Text(0.5, 1.0, 'Correlation between Influence to selection')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import (StandardScaler, PolynomialFeatures)
mlr = LinearRegression()
X = df_1[['Recommend by A Friend', 'Price', 'Family plan', 'Advertisements', 'Music Recommendations', 'Collaborative Playlist Features']]
y = df_1[["Current Music Streaming Service"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42) #split into train and test parts
s = StandardScaler()
X_train_sm = s.fit_transform(X_train)
mlr.fit(X_train_sm, y_train)
X_test_sm = s.transform(X_test)
y_pred_sm = mlr.predict(X_test_sm)

# %%
print(f'R2 score is {r2_score(y_pred_sm,y_test)}')
print("Residual sum of squares (MSE): %.2f" % np.mean((y_pred_sm - y_test) ** 2))
print(X.columns)
print(f'Co-efficients are {mlr.coef_}')
print(f'Intercept is {mlr.intercept_}')
# Out:
# R2 score is -2.348446243283537
# Residual sum of squares (MSE): 0.46
# Index(['Recommend by A Friend', 'Price', 'Family plan', 'Advertisements',
#        'Music Recommendations', 'Collaborative Playlist Features'],
#       dtype='object')
# Co-efficients are [[-0.35786786 -0.05247492  0.09722801 -0.30989333 -0.18231511  0.57899543]]
# Intercept is [1.37037037]

# %%
df_2 = df_n.loc[:,['Q8_3','Q9_3']]
df_2 = df_2.dropna()
df_2.shape
# Out:
# (53, 2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import (StandardScaler, PolynomialFeatures)
slr = LinearRegression()
X = df_2[['Q9_3']]
y = df_2[["Q8_3"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
s = StandardScaler()
X_train_s = s.fit_transform(X_train)
slr.fit(X_train_s, y_train)
X_test_s = s.transform(X_test)
y_pred = slr.predict(X_test_s)
print(f'R2 score is {r2_score(y_pred,y_test)}')
print(f'Co-efficients are {slr.coef_}')
print(f'Intercept is {slr.intercept_}')
# Out:
# R2 score is -7.747594832885381
# Co-efficients are [[0.34439319]]
# Intercept is [5.42553191]

# %%
plt.figure(figsize = (15,9))
sns.regplot(X_test_s,y_pred,scatter_kws={"color": "red"},line_kws={"color": "green"})
plt.xlabel('Satisfaction')
plt.ylabel('Importance')
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Importance')

# %%
plt.figure(figsize=(10, 10))
df_1=df.loc[:,['Q8_1','Q8_2','Q8_3','Q8_4','Q8_5','Q8_6',]]
sns.heatmap(df_1.corr(), vmax=.7, linewidths=0.01,square=True,annot=True,cmap='Greens' ,linecolor="white")
plt.title('Correlation between platform features')
# Out:
# Text(0.5, 1.0, 'Correlation between platform features')

# %%
plt.figure(figsize = (15,9))
sns.regplot(df['Q10_1'],df['Q11_17'],scatter_kws={"color": "red"},line_kws={"color": "green"})
plt.xlabel('satisfaction')
plt.ylabel('willing to switch')
plt.title("Relationship between people's satisfaction and willingness to switch")
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, "Relationship between people's satisfaction and willingness to switch")

# %%
data = [['User_Interface', 5.6,5.9], ['Available Music collection', 6.4,5.7], ['Subscription fee', 5.5,5.5],
       ['Student Discounts', 5.0,5.4], ['Offers Music Recommendations', 4.8,5.6], ['Available Podcasts', 3.6,5.3]]
df_new = pd.DataFrame(data, columns = ['Feature', 'Importance', 'Satisfaction'])
df_new
# Out:
#                         Feature  Importance  Satisfaction
# 0                User_Interface         5.6           5.9
# 1    Available Music collection         6.4           5.7
# 2              Subscription fee         5.5           5.5
# 3             Student Discounts         5.0           5.4
# 4  Offers Music Recommendations         4.8           5.6
# 5            Available Podcasts         3.6           5.3

# %%
fig, ax = plt.subplots(figsize=(8,8))
sns.scatterplot(x ='Importance', y ='Satisfaction',data = df_new, hue='Feature', style = 'Feature', s=700)
# Out:
# <AxesSubplot:xlabel='Importance', ylabel='Satisfaction'>
